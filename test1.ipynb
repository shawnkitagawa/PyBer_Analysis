# %%
import matplotlib.pyplot as plt
import statistics

# %%
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# %%
plt.plot(x_axis, y_axis, label = "savings")
plt.xlabel("Month")
plt.ylabel("Money$")

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,8))
ax.plot(x_axis, y_axis)
ax.grid()
ax.set_ylim(0,50)
# Out:
# (0.0, 50.0)

# %%
fig = plt.figure()
ax = fig.add_subplot()

# %%
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis, linewidth = 2, color = "green", marker = "d", label = "Boston")
ax.set_ylim(0,45)
ax.set_title("PyBer Fare by Month")
ax.set_xlabel("Month")
ax.set_ylabel("Fare ($)")

ax.legend()

plt.show()

# %%
plt.bar(x_axis, y_axis, label = "Boston")
plt.xlabel("Month")
plt.ylabel("Fare ($)")
plt.legend()
plt.title("Pyber Fare by Month")


plt.show()

# %%
plt.barh(x_axis, y_axis, label = "Boston")
plt.gca().invert_yaxis()
plt.xlabel("Month")
plt.ylabel("Fare ($)")
plt.legend()
plt.title("Pyber Fare by Month")


plt.show()

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color = "magenta", label = "Boston")
ax.invert_yaxis()
ax.set_title("Pyber Fare by Month")
ax.set_ylabel("Date")
ax.set_xlabel("Fare ($)")

plt.show()

# %%
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color = "cyan", label = "Chicago")
ax.set_xlabel("Fare ($)")
ax.set_ylabel("Date")
ax.set_title("Pyber Fare by Month")
ax.invert_yaxis()
ax.legend()

plt.show()

# %%
plt.plot(x_axis, y_axis,"o")

# %%
plt.scatter(x_axis, y_axis)

# %%
plt.scatter(y_axis, x_axis, color = "red", label = "Chicago")
plt.xlabel("Fare($)")
plt.ylabel("Date")
plt.title("PyBer Fare by Month")


plt.legend()
plt.show()

# %%
y_axis_larger = []

for i in y_axis:
    y_axis_larger.append(i*3)
plt.scatter(x_axis, y_axis, s = y_axis_larger)

# %%
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, label = "Boston", color = "skyblue", s = [data * 3 for data in y_axis], alpha = 0.8, edgecolor = "black")
ax.legend()
ax.invert_yaxis()
ax.set_title("Pyber Fare by Month")
ax.set_xlabel("Fare ($)")
ax.set_ylabel("Month")
ax.set_xlim(0,50)




plt.show()

# %%
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize = (8,8))
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')


plt.show()

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()

# %%
fig, ax = plt.subplots()
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
ax.pie(y_axis, explode = explode_values, autopct = "%.1f%%", startangle = 265,labels = x_axis)
ax.invert_yaxis()

plt.show()

# %%
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis, y_axis, yerr = stdev, capsize = 3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
import numpy as np
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0,51,step = 5.0))
plt.gca().invert_yaxis()


ax.xaxis.set_minor_locator()
plt.show()
